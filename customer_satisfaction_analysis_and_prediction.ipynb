# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("main_123.csv")

# %%
df.head(5)
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied    Male  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Female  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Female  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Female  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# ...

# %%
df.shape
# Out:
# (129880, 23)

# %% [markdown]
# first challange yes, there is nulls in the column 'Arrival Delay in Minutes'

# %% [markdown]
# lets check data type validation in the column 'Departure Delay in Minutes'
# we read after searching that more valid be float,
# So we need to convert it into float

# %% [markdown]
# lets check duplication using the function 'duplicated'

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# lets show summary of our statistics in our data use the fun 'describe'

# %%
df.describe()
# Out:
#                  Age  Flight Distance   Seat comfort  \
# count  129880.000000    129880.000000  129880.000000
# mean       39.427957      1981.409055       2.838597
# std        15.119360      1027.115606       1.392983
# min         7.000000        50.000000       0.000000
# 25%        27.000000      1359.000000       2.000000
# 50%        40.000000      1925.000000       3.000000
# 75%        51.000000      2544.000000       4.000000
# max        85.000000      6951.000000       5.000000
#
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# count                      129880.000000   129880.000000  129880.000000
# mean                            2.990645        2.851994       2.990422
# std                             1.527224        1.443729       1.305970
# min                             0.000000        0.000000       0.000000
# 25%                             2.000000        2.000000       2.000000
# ...

# %% [markdown]
# i want see our data in two status which value of the column 'Departure Delay in Minutes' is  1592.000000 and value of the column  'Arrival Delay in Minutes' is 1584.000000
# Also i want check value of the column 'Flight Distance' is 6951.000000

# %%
df[df['Departure Delay in Minutes']==1592.000000].describe() # two see all our columns and its values of its categories
# Out:
#         Age  Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# count   1.0              1.0           1.0                                1.0
# mean   47.0           3113.0           2.0                                2.0
# std     NaN              NaN           NaN                                NaN
# min    47.0           3113.0           2.0                                2.0
# 25%    47.0           3113.0           2.0                                2.0
# 50%    47.0           3113.0           2.0                                2.0
# 75%    47.0           3113.0           2.0                                2.0
# max    47.0           3113.0           2.0                                2.0
#
#        Food and drink  Gate location  Inflight wifi service  \
# count             1.0            1.0                    1.0
# mean              2.0            3.0                    2.0
# std               NaN            NaN                    NaN
# ...

# %%
df[df['Arrival Delay in Minutes']==1584.000000]
# Out:
#       satisfaction  Gender   Customer Type  Age   Type of Travel Class  \
# 9704  dissatisfied  Female  Loyal Customer   47  Personal Travel   Eco
#
#       Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 9704             3113             2                                  2
#
#       Food and drink  ...  Online support  Ease of Online booking  \
# 9704               2  ...               2                       2
#
#       On-board service  Leg room service  Baggage handling  Checkin service  \
# 9704                 4                 4                 4                2
#
#       Cleanliness  Online boarding  Departure Delay in Minutes  \
# 9704            3                2                        1592
#
#       Arrival Delay in Minutes
# 9704                    1584.0
#
# [1 rows x 23 columns]

# %% [markdown]
# i think this female although is loyal ,she sufferd from delay of deprature and arrival also Seat comfort	,
# Food and drink ,Inflight wifi service,Ease of Online booking ,Checkin service and Online boarding

# %%
df[df['Flight Distance']==6951.000000]
# Out:
#        satisfaction Gender      Customer Type  Age   Type of Travel     Class  \
# 49083  dissatisfied   Male  disloyal Customer   42  Business travel  Business
#
#        Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 49083             6951             2                                  2
#
#        Food and drink  ...  Online support  Ease of Online booking  \
# 49083               2  ...               1                       3
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# 49083                 3                 4                 5                1
#
#        Cleanliness  Online boarding  Departure Delay in Minutes  \
# 49083            4                1                           1
#
#        Arrival Delay in Minutes
# 49083                      25.0
#
# [1 rows x 23 columns]

# %% [markdown]
# i think it is a Business trave and every delay effect badlly and  he not loyal customer make most rates are ones but we can check if our organization leads well in deep ditance or not

# %%
df[(df['Flight Distance']<=6951.000000 )& (df['Flight Distance']>=2544.000000)].satisfaction.value_counts()
# Out:
# satisfaction
# satisfied       19397
# dissatisfied    13076
# Name: count, dtype: int64

# %% [markdown]
# Yse, our organization leads well in deep ditance

# %% [markdown]
# # Data cleaning

# %% [markdown]
# First , Try to treatment with nulls

# %% [markdown]
# we fill every null value with mean of values of the column 'Arrival Delay in Minutes'

# %%
df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].mean(),inplace=True)
# Out:
# C:\Users\katty\AppData\Local\Temp\ipykernel_20080\3756272697.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].mean(),inplace=True)

# %% [markdown]
# test it

# %% [markdown]
# Seconed, Try to covnvet type of values of the column 'Departure Delay in Minutes'  and the column 'flight distance'

# %%
df['Departure Delay in Minutes']=df['Departure Delay in Minutes'].astype('float')
df['Flight Distance']=df['Flight Distance'].astype('float')

# %% [markdown]
# test it

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  float64
#  7   Seat comfort                       129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
# ...

# %% [markdown]
# # Data analysis

# %%
# to know what is trendy in our data
df.describe(include='object')
# Out:
#        satisfaction  Gender   Customer Type   Type of Travel     Class
# count        129880  129880          129880           129880    129880
# unique            2       2               2                2         3
# top       satisfied  Female  Loyal Customer  Business travel  Business
# freq          71087   65899          106100            89693     62160

# %% [markdown]
# what is top or trendy in measers

# %%
print(df['Seat comfort'].value_counts())# 3 is treny rate in 'Seat comfort'
df = df.drop(df[df['Seat comfort'] == 0].index)
print(df['Seat comfort'].value_counts())
# Out:
# Seat comfort
# 3    29183
# 2    28726
# 4    28398
# 1    20949
# 5    17827
# 0     4797
# Name: count, dtype: int64
# Seat comfort
# 3    29183
# 2    28726
# 4    28398
# 1    20949
# 5    17827
# Name: count, dtype: int64

# %%
print(df['Departure/Arrival time convenient'].value_counts()) # 4 is treny rate in 'Departure/Arrival time convenient'
df = df.drop(df[df['Departure/Arrival time convenient'] == 0].index)
print(df['Departure/Arrival time convenient'].value_counts())
# Out:
# Departure/Arrival time convenient
# 4    28624
# 5    25905
# 3    22879
# 2    22651
# 1    20570
# 0     4454
# Name: count, dtype: int64
# Departure/Arrival time convenient
# 4    28624
# 5    25905
# 3    22879
# 2    22651
# 1    20570
# Name: count, dtype: int64

# %%
print(df['Food and drink'].value_counts())# 3 is treny rate in 'Food and drink'
df = df.drop(df[df['Food and drink'] == 0].index)
print(df['Food and drink'].value_counts())
# Out:
# Food and drink
# 3    27278
# 2    26295
# 4    26168
# 1    20276
# 5    19618
# 0      994
# Name: count, dtype: int64
# Food and drink
# 3    27278
# 2    26295
# 4    26168
# 1    20276
# 5    19618
# Name: count, dtype: int64

# %%
print(df['Gate location'].value_counts())# 3 is treny rate in 'Gate location'
df = df.drop(df[df['Gate location'] == 0].index)
print(df['Gate location'].value_counts())
# Out:
# Gate location
# 3    30597
# 4    27582
# 2    22565
# 1    20648
# 5    18243
# Name: count, dtype: int64
# Gate location
# 3    30597
# 4    27582
# 2    22565
# 1    20648
# 5    18243
# Name: count, dtype: int64

# %%
print(df['Inflight wifi service'].value_counts())# 4 is treny rate in 'Inflight wifi service'
df = df.drop(df[df['Inflight wifi service'] == 0].index)
print(df['Inflight wifi service'].value_counts())
# Out:
# Inflight wifi service
# 4    29378
# 5    26656
# 3    25388
# 2    24912
# 1    13297
# 0        4
# Name: count, dtype: int64
# Inflight wifi service
# 4    29378
# 5    26656
# 3    25388
# 2    24912
# 1    13297
# Name: count, dtype: int64

# %%
print(df['Inflight entertainment'].value_counts())# 4 is treny rate in 'Inflight entertainment'
df = df.drop(df[df['Inflight entertainment'] == 0].index)
print(df['Inflight entertainment'].value_counts())
# Out:
# Inflight entertainment
# 4    39663
# 5    28040
# 3    22943
# 2    18082
# 1    10889
# 0       14
# Name: count, dtype: int64
# Inflight entertainment
# 4    39663
# 5    28040
# 3    22943
# 2    18082
# 1    10889
# Name: count, dtype: int64

# %%
print(df['Online support'].value_counts())# 4 is treny rate in 'Online support'
df = df.drop(df[df['Online support'] == 0].index)
print(df['Online support'].value_counts())
# Out:
# Online support
# 4    38811
# 5    33037
# 3    19802
# 2    15582
# 1    12384
# 0        1
# Name: count, dtype: int64
# Online support
# 4    38811
# 5    33037
# 3    19802
# 2    15582
# 1    12384
# Name: count, dtype: int64

# %%
print(df['Ease of Online booking'].value_counts())# 4 is treny rate in 'Ease of Online booking'
df = df.drop(df[df['Ease of Online booking'] == 0].index)
print(df['Ease of Online booking'].value_counts())
# Out:
# Ease of Online booking
# 4    37709
# 5    32022
# 3    20225
# 2    17910
# 1    11745
# 0        5
# Name: count, dtype: int64
# Ease of Online booking
# 4    37709
# 5    32022
# 3    20225
# 2    17910
# 1    11745
# Name: count, dtype: int64

# %%
print(df['On-board service'].value_counts())# 4 is treny rate in 'On-board service'
df = df.drop(df[df['On-board service'] == 0].index)
print(df['On-board service'].value_counts())
# Out:
# On-board service
# 4    38041
# 5    29371
# 3    24418
# 2    15801
# 1    11980
# Name: count, dtype: int64
# On-board service
# 4    38041
# 5    29371
# 3    24418
# 2    15801
# 1    11980
# Name: count, dtype: int64

# %%
print(df['Leg room service'].value_counts())# 4 is treny rate in 'Leg room service'
df = df.drop(df[df['Leg room service'] == 0].index)
print(df['Leg room service'].value_counts())
# Out:
# Leg room service
# 4    37525
# 5    32194
# 3    20384
# 2    19641
# 1     9867
# Name: count, dtype: int64
# Leg room service
# 4    37525
# 5    32194
# 3    20384
# 2    19641
# 1     9867
# Name: count, dtype: int64

# %%
print(df['Baggage handling'].value_counts())# 4 is treny rate in 'Baggage handling'
df = df.drop(df[df['Baggage handling'] == 0].index)
print(df['Baggage handling'].value_counts())
# Out:
# Baggage handling
# 4    45016
# 5    32794
# 3    22830
# 2    12161
# 1     6810
# Name: count, dtype: int64
# Baggage handling
# 4    45016
# 5    32794
# 3    22830
# 2    12161
# 1     6810
# Name: count, dtype: int64

# %%
print(df['Checkin service'].value_counts())# 4 is treny rate in 'Checkin service'
df = df.drop(df[df['Checkin service'] == 0].index)
print(df['Checkin service'].value_counts())
# Out:
# Checkin service
# 4    33673
# 3    32774
# 5    24496
# 2    14397
# 1    14271
# Name: count, dtype: int64
# Checkin service
# 4    33673
# 3    32774
# 5    24496
# 2    14397
# 1    14271
# Name: count, dtype: int64

# %%
print(df['Cleanliness'].value_counts())# 4 is treny rate in 'Cleanliness'
df = df.drop(df[df['Cleanliness'] == 0].index)
print(df['Cleanliness'].value_counts())
# Out:
# Cleanliness
# 4    45434
# 5    32991
# 3    22323
# 2    12176
# 1     6687
# Name: count, dtype: int64
# Cleanliness
# 4    45434
# 5    32991
# 3    22323
# 2    12176
# 1     6687
# Name: count, dtype: int64

# %%
print(df['Online boarding'].value_counts())# 4is treny rate in 'Online boarding'
df = df.drop(df[df['Online boarding'] == 0].index)
print(df['Online boarding'].value_counts())
# Out:
# Online boarding
# 4    32758
# 3    28357
# 5    27764
# 2    16835
# 1    13897
# Name: count, dtype: int64
# Online boarding
# 4    32758
# 3    28357
# 5    27764
# 2    16835
# 1    13897
# Name: count, dtype: int64

# %% [markdown]
# there are zeroes we arenot interested of them so we dropped them

# %%
# we can make it as bins and labels 
print(df['Age'])                               
bin_edges = [6, 12, 19, 35, 55, 70]  # our bins we assumed
bin_labels = ['Children', 'Teenagers', 'Young Adults', 'Adults', 'Seniors']# our labels we assumed


df['Age Grouped'] = pd.cut(df['Age'], bins=bin_edges, labels=bin_labels)


df[['Age', 'Age Grouped']]
# Out:
# 1037      48
# 1038      48
# 1041      40
# 1043      46
# 1044      63
#           ..
# 129874    11
# 129875    29
# 129876    63
# 129878    66
# 129879    38
# Name: Age, Length: 119611, dtype: int64
#         Age   Age Grouped
# 1037     48        Adults
# 1038     48        Adults
# 1041     40        Adults
# 1043     46        Adults
# 1044     63       Seniors
# ...     ...           ...
# 129874   11      Children
# 129875   29  Young Adults
# 129876   63       Seniors
# 129878   66       Seniors
# 129879   38        Adults
#
# [119611 rows x 2 columns]

# %% [markdown]
# # visuallization

# %% [markdown]
# lets check relation between measures and satisfaction

# %%
# how many satisfied passengers fall within each seat comfort rates
plt.subplot(1,2,1)
sns.countplot(x=df['Seat comfort'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_seat = satisfied_passengers.groupby('Seat comfort').count()['satisfaction']


plt.bar(satisfaction_by_seat.index, satisfaction_by_seat.values,linestyle='--')


plt.xlabel('Seat Comfort Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Seat Comfort Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by Seat Comfort Rating')

# %%
# how many satisfied passengers fall within each Departure/Arrival time convenient rates
plt.subplot(1,2,1)
sns.countplot(x=df['Departure/Arrival time convenient'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Departure/Arrival time convenient').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('Departure/Arrival time convenient Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Departure/Arrival time convenient Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by Departure/Arrival time convenient Rating')

# %%
# how many satisfied passengers fall within each Food and drink rates
plt.subplot(1,2,1)
sns.countplot(x=df['Food and drink'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Food and drink').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('Food and drink Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Food and drink Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by Food and drink Rating')

# %%
# how many satisfied passengers fall within each Gate location rates
plt.subplot(1,2,1)
sns.countplot(x=df['Gate location'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Gate location').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('Gate locationR ating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Gate location Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by Gate location Rating')

# %%
# how many satisfied passengers fall within each Inflight wifi service rates
plt.subplot(1,2,1)
sns.countplot(x=df['Inflight wifi service'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Inflight wifi service').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('Inflight wifi service Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Inflight wifi service Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by Inflight wifi service Rating')

# %%
# how many satisfied passengers fall within each Inflight entertainment rates
plt.subplot(1,2,1)
sns.countplot(x=df['Inflight entertainment'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Inflight entertainment').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('Inflight entertainment Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Inflight entertainment Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by Inflight entertainment Rating')

# %%
# how many satisfied passengers fall within each Ease of Online booking rates
plt.subplot(1,2,1)
sns.countplot(x=df['Ease of Online booking'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Ease of Online booking').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('Ease of Online booking Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Ease of Online booking Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by Ease of Online booking Rating')

# %%
# how many satisfied passengers fall within each On-board service rates
plt.subplot(1,2,1)
sns.countplot(x=df['On-board service'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('On-board service').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('On-board service Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by On-board service Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by On-board service Rating')

# %%
# how many satisfied passengers fall within each Leg room service rates
plt.subplot(1,2,1)
sns.countplot(x=df['Leg room service'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Leg room service').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('Leg room service Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Leg room service Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by Leg room service Rating')

# %%
# how many satisfied passengers fall within each Baggage handling rates
plt.subplot(1,2,1)
sns.countplot(x=df['Baggage handling'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Baggage handling').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('Baggage handling Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Baggage handling Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by Baggage handling Rating')

# %%
# how many satisfied passengers fall within each Checkin service rates
plt.subplot(1,2,1)
sns.countplot(x=df['Checkin service'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Checkin service').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('Checkin service Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Checkin service Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by Checkin service Rating')

# %%
# how many satisfied passengers fall within each cleanliness rates
plt.subplot(1,2,1)
sns.countplot(x=df['Cleanliness'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Cleanliness').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('cleanliness Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by cleanlinesss Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by cleanlinesss Rating')

# %%
# how many satisfied passengers fall within each online boarding rates
plt.subplot(1,2,1)
sns.countplot(x=df['Online boarding'])


plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Online boarding').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('Online boarding Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Online boarding Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Satisfied Passengers by Online boarding Rating')

# %%
# how many satisfied passengers fall within each age category
plt.subplot(1,2,1)
sns.countplot(x=df['Age Grouped'])
plt.xticks(rotation=45)

plt.show()
plt.subplot(1,2,2)

satisfied_passengers = df[df['satisfaction'] == 'satisfied']


satisfaction_by_ = satisfied_passengers.groupby('Age Grouped').count()['satisfaction']


plt.bar(satisfaction_by_.index, satisfaction_by_.values)


plt.xlabel('Age Grouped Rating')
plt.ylabel('Number of Satisfied Passengers')
plt.title('Distribution of Satisfied Passengers by Age Grouped')
plt.xticks(rotation=45)
# Out:
# c:\Users\katty\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\katty\AppData\Local\Temp\ipykernel_20080\2997791741.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   satisfaction_by_ = satisfied_passengers.groupby('Age Grouped').count()['satisfaction']
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Children'),
#   Text(1, 0, 'Teenagers'),
#   Text(2, 0, 'Young Adults'),
#   Text(3, 0, 'Adults'),
#   Text(4, 0, 'Seniors')])

# %% [markdown]
# our organization must focuse on seat comfort,Departure/Arrival time,gate location,food and drink , wifi

# %%
sns.scatterplot(x=df['Departure Delay in Minutes'],y=df['Arrival Delay in Minutes'],hue=df['satisfaction'])
# Out:
# <Axes: xlabel='Departure Delay in Minutes', ylabel='Arrival Delay in Minutes'>

# %% [markdown]
# from 0 and 500 in both Departure  and arrival Delay in Minutes staified poeple major, more than 500 in both disstaified poeple major and general distrubtion reduce

# %%
sns.barplot(x=df['Customer Type'],y=df['Arrival Delay in Minutes'],hue=df['satisfaction'])
plt.show()
sns.barplot(x=df['Customer Type'],y=df['Departure Delay in Minutes'],hue=df['satisfaction'])
plt.show()

# %%
sns.countplot(x=df['Age Grouped'],hue=df['satisfaction'])
plt.show()
# Out:
# c:\Users\katty\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# c:\Users\katty\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
for col in df.columns:
    if df[col].dtype=='int'and (col!='Age'and col!='satisfaction' ) :
        sns.countplot(x=df[col],hue=df['satisfaction'])
        plt.show()

# %% [markdown]
# # Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
for col in df.columns:
    if df[col].dtype=='object':
        l_en=LabelEncoder()
        df[col] = l_en.fit_transform(df[col])

# %%
x = df[['Seat comfort','Inflight entertainment','Ease of Online booking','Online support','Gender',
                   'Customer Type', 'Type of Travel', 'Class','On-board service', 'Leg room service', 'Online boarding']]
y = df["satisfaction"]

# %% [markdown]
# # Data modeling

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

model=DecisionTreeClassifier(max_depth=17)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)


print("Accuracy = {}".format(accuracy))
# Out:
# Accuracy = 0.9298294504514547

# %%
#most important column after fitting
z=model.feature_importances_

# %%
feature_importance_dict = {
    'Feature': x.columns,
    'Importance': z
}


feature_importance_df = pd.DataFrame(feature_importance_dict)


feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)


plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.show()
